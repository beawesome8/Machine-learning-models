# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('wine_quality.csv')
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head(10)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
# 5            7.4              0.66         0.00             1.8      0.075
# 6            7.9              0.60         0.06             1.6      0.069
# 7            7.3              0.65         0.00             1.2      0.065
# 8            7.8              0.58         0.02             2.0      0.073
# 9            7.5              0.50         0.36             6.1      0.071
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
df.tail(10)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1589            6.6             0.725         0.20             7.8      0.073
# 1590            6.3             0.550         0.15             1.8      0.077
# 1591            5.4             0.740         0.09             1.7      0.089
# 1592            6.3             0.510         0.13             2.3      0.076
# 1593            6.8             0.620         0.08             1.9      0.068
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
df.sample(5)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 319             9.6              0.77         0.12             2.9      0.082
# 1184            6.7              0.64         0.23             2.1      0.080
# 1221           10.9              0.32         0.52             1.8      0.132
# 470            13.0              0.32         0.65             2.6      0.093
# 451             8.4              0.37         0.53             1.8      0.413
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 319                  30.0                  74.0  0.99865  3.30       0.64
# 1184                 11.0                 119.0  0.99538  3.36       0.70
# 1221                 17.0                  44.0  0.99734  3.28       0.77
# 470                  15.0                  47.0  0.99960  3.05       0.61
# 451                   9.0                  26.0  0.99790  3.06       1.06
#
#       alcohol  quality
# 319      10.4        6
# ...

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
df.shape
# Out:
# (1599, 12)

# %% [markdown]
# # EDA

# %%
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %% [markdown]
# # ScatterPLot:

# %%
import seaborn as sns

# %%
sns.scatterplot(x='fixed acidity',y='quality',data=df)

# %%
sns.scatterplot(x='volatile acidity',y='quality',data=df)

# %%
sns.scatterplot(x='citric acid',y='quality',data=df)

# %%
sns.scatterplot(x='residual sugar',y='quality',data=df)

# %%
sns.scatterplot(x='chlorides',y='quality',data=df)

# %%
sns.scatterplot(x='free sulfur dioxide',y='quality',data=df)

# %%
sns.scatterplot(x='total sulfur dioxide',y='quality',data=df)

# %%
sns.scatterplot(x='density',y='quality',data=df)

# %%
sns.scatterplot(x='pH',y='quality',data=df)

# %%
sns.scatterplot(x='sulphates',y='quality',data=df)

# %%
sns.scatterplot(x='alcohol',y='quality',data=df)

# %%
sns.pairplot(df)

# %% [markdown]
# # Correlation:

# %%
df.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
df.corr()['quality'].sort_values()
# Out:
# volatile acidity       -0.390558
# total sulfur dioxide   -0.185100
# density                -0.174919
# chlorides              -0.128907
# pH                     -0.057731
# free sulfur dioxide    -0.050656
# residual sugar          0.013732
# fixed acidity           0.124052
# citric acid             0.226373
# sulphates               0.251397
# alcohol                 0.476166
# quality                 1.000000
# Name: quality, dtype: float64

# %% [markdown]
# correlation using heatmap:

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(15,10))
sns.heatmap(df.corr(),annot=True,linewidths=0.5,linecolor='black',fmt='.2f')

# %% [markdown]
# # Descriptive statistics

# %% [markdown]
# # Describing Data Sets

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
plt.figure(figsize=(15,12))
sns.heatmap(round(df.describe()[1:].transpose(),2),linewidth=2,annot=True,fmt='f')
plt.xticks(fontsize=18)
plt.yticks(fontsize=12)
plt.title('Variables summary')
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %% [markdown]
# # Outlier Checking

# %%
import warnings 
warnings.filterwarnings('ignore')

# %%
plt.figure(figsize=(10,7))
sns.countplot(x ='quality', data = df)
plt.xlabel('Quality of Red Wine')
plt.ylabel('Count of Rows in the dataset')
plt.show()

# %%
collist=df.columns.values
ncol=30
nrows=14
plt.figure(figsize=(2*ncol,5*ncol))
for i in range (0,len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.boxplot(df[collist[i]],color='blue',orient='v')
    plt.tight_layout()

# %% [markdown]
# as we can observe the box plot that a lot of outliers are present

# %% [markdown]
# # skewness

# %%
df.skew()
# Out:
# fixed acidity           0.982751
# volatile acidity        0.671593
# citric acid             0.318337
# residual sugar          4.540655
# chlorides               5.680347
# free sulfur dioxide     1.250567
# total sulfur dioxide    1.515531
# density                 0.071288
# pH                      0.193683
# sulphates               2.428672
# alcohol                 0.860829
# quality                 0.217802
# dtype: float64

# %% [markdown]
# # Normal Distribution Curve:

# %%
sns.distplot(df['fixed acidity'],hist=False,color='blue',kde_kws={"shade": True})

# %%
sns.distplot(df['volatile acidity'],hist=False,color='blue',kde_kws={"shade": True})

# %%
sns.distplot(df['citric acid'],hist=False,color='blue',kde_kws={"shade": True})

# %%
sns.distplot(df['residual sugar'],hist=False,color='blue',kde_kws={"shade": True})

# %%
sns.distplot(df['chlorides'],hist=False,color='blue',kde_kws={"shade": True})

# %%
sns.distplot(df['free sulfur dioxide'],hist=False,color='blue',kde_kws={"shade": True})

# %%
sns.distplot(df['total sulfur dioxide'],hist=False,color='blue',kde_kws={"shade": True})

# %%
sns.distplot(df['density'],hist=False,color='blue',kde_kws={"shade": True})

# %%
sns.distplot(df['pH'],hist=False,color='blue',kde_kws={"shade": True})

# %%
sns.distplot(df['sulphates'],hist=False,color='blue',kde_kws={"shade": True})

# %%
sns.distplot(df['alcohol'],hist=False,color='blue',kde_kws={"shade": True})

# %%
sns.distplot(df['quality'],hist=False,color='blue',kde_kws={"shade": True})

# %% [markdown]
# # Data Cleaning:

# %%
df.corr()['quality']
# Out:
# fixed acidity           0.124052
# volatile acidity       -0.390558
# citric acid             0.226373
# residual sugar          0.013732
# chlorides              -0.128907
# free sulfur dioxide    -0.050656
# total sulfur dioxide   -0.185100
# density                -0.174919
# pH                     -0.057731
# sulphates               0.251397
# alcohol                 0.476166
# quality                 1.000000
# Name: quality, dtype: float64

# %%
df = df.drop('free sulfur dioxide', axis=1)
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %% [markdown]
# # Removing Outliers:

# %%
from scipy.stats import zscore
import numpy as np
z=np.abs(zscore(df))
z.shape
# Out:
# (1599, 11)

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([  13,   15,   17,   17,   19,   33,   38,   42,   43,   45,   81,
#          81,   83,   86,   88,   91,   92,   95,  106,  106,  109,  120,
#         126,  127,  142,  144,  147,  151,  151,  151,  151,  163,  164,
#         169,  169,  181,  199,  226,  226,  240,  243,  244,  258,  258,
#         274,  281,  291,  324,  325,  339,  340,  347,  354,  374,  381,
#         391,  396,  400,  442,  442,  451,  459,  467,  480,  480,  494,
#         515,  517,  544,  554,  554,  555,  555,  557,  557,  568,  588,
#         591,  595,  608,  614,  636,  639,  649,  649,  651,  652,  652,
#         652,  672,  672,  684,  690,  690,  692,  692,  695,  723,  724,
#         730,  754,  776,  777,  795,  821,  832,  836,  837,  889,  899,
#         911,  917,  923, 1017, 1018, 1043, 1051, 1051, 1071, 1074, 1079,
#        1079, 1081, 1081, 1111, 1114, 1165, 1186, 1235, 1244, 1244, 1260,
#        1269, 1269, 1270, 1270, 1288, 1289, 1299, 1299, 1300, 1312, 1316,
# ...

# %%
#taking any random index values location
df.iloc[1043]
# Out:
# fixed acidity            9.50000
# volatile acidity         0.39000
# citric acid              0.41000
# residual sugar           8.90000
# chlorides                0.06900
# total sulfur dioxide    39.00000
# density                  0.99859
# pH                       3.29000
# sulphates                0.81000
# alcohol                 10.90000
# quality                  7.00000
# Name: 1043, dtype: float64

# %%
df.drop([  13,   14,   15,   15,   17,   17,   19,   33,   38,   42,   43,
         45,   57,   81,   81,   83,   86,   88,   91,   92,   95,  106,
        106,  109,  120,  126,  127,  142,  144,  147,  151,  151,  151,
        151,  163,  164,  169,  169,  181,  199,  226,  226,  240,  243,
        244,  258,  258,  274,  281,  291,  324,  325,  339,  340,  347,
        354,  374,  381,  391,  396,  396,  400,  400,  442,  442,  451,
        459,  467,  480,  480,  494,  515,  517,  544,  554,  554,  555,
        555,  557,  557,  568,  584,  588,  591,  595,  608,  614,  636,
        639,  649,  649,  651,  652,  652,  652,  672,  672,  684,  690,
        690,  692,  692,  695,  723,  724,  730,  754,  776,  777,  795,
        821,  832,  836,  837,  889,  899,  911,  917,  923,  925,  926,
        982, 1017, 1018, 1043, 1051, 1051, 1071, 1074, 1079, 1079, 1081,
       1081, 1111, 1114, 1131, 1154, 1165, 1175, 1186, 1231, 1235, 1244,
       1244, 1244, 1260, 1269, 1269, 1270, 1270, 1288, 1289, 1295, 1296,
       1299, 1299, 1300, 1312, 1316, 1319, 1319, 1321, 1358, 1367, 1370,
       1370, 1372, 1372, 1374, 1374, 1434, 1434, 1434, 1435, 1435, 1435,
       1469, 1474, 1474, 1474, 1476, 1476, 1476, 1478, 1493, 1496, 1505,
       1558, 1558, 1570, 1574, 1589])
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df_new=df[(z<3).all(axis=1)]
print('Old Dataframe',df.shape)
print('New Dataframe',df_new.shape)
print('total_dropped_rows',df.shape[0]-df_new.shape[0])
# Out:
# Old Dataframe (1599, 11)
# New Dataframe (1464, 11)
# total_dropped_rows 135

# %% [markdown]
# # Percentage Data Loss

# %%
loss_percent=(148/1599)*100
print(loss_percent,'%')
# Out:
# 9.255784865540964 %

# %% [markdown]
# # Dividing the data into features and vectors:

# %%
df_new
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
#independent column
x=df_new.iloc[:,:-1]
#target
y=df_new.iloc[:,-1]
print(x.shape)
print(y.shape)
# Out:
# (1464, 10)
# (1464,)

# %% [markdown]
# # Transforming data to remove skewness

# %%
from sklearn.preprocessing import power_transform
x=power_transform(x,method='yeo-johnson')
x
# Out:
# array([[-4.42665887e-01,  9.95541630e-01, -1.53110932e+00, ...,
#          1.27568965e+00, -5.81649810e-01, -1.07502541e+00],
#        [-1.61307687e-01,  1.77129873e+00, -1.53110932e+00, ...,
#         -7.09517433e-01,  3.95139954e-01, -5.00859609e-01],
#        [-1.61307687e-01,  1.26980139e+00, -1.25535866e+00, ...,
#         -3.10054073e-01,  1.83771552e-01, -5.00859609e-01],
#        ...,
#        [-1.36436736e+00,  3.87065014e-04, -6.83293826e-01, ...,
#          7.18868617e-01,  8.20841495e-01,  7.34557526e-01],
#        [-1.76745837e+00,  7.28552770e-01, -7.43826364e-01, ...,
#          1.63859528e+00,  5.88343819e-01, -1.87998601e-02],
#        [-1.66263981e+00, -1.32045850e+00,  1.03107021e+00, ...,
#          5.29831617e-01,  2.56369273e-01,  7.34557526e-01]])

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(x)
x
# Out:
# array([[-4.42665887e-01,  9.95541630e-01, -1.53110932e+00, ...,
#          1.27568965e+00, -5.81649810e-01, -1.07502541e+00],
#        [-1.61307687e-01,  1.77129873e+00, -1.53110932e+00, ...,
#         -7.09517433e-01,  3.95139954e-01, -5.00859609e-01],
#        [-1.61307687e-01,  1.26980139e+00, -1.25535866e+00, ...,
#         -3.10054073e-01,  1.83771552e-01, -5.00859609e-01],
#        ...,
#        [-1.36436736e+00,  3.87065014e-04, -6.83293826e-01, ...,
#          7.18868617e-01,  8.20841495e-01,  7.34557526e-01],
#        [-1.76745837e+00,  7.28552770e-01, -7.43826364e-01, ...,
#          1.63859528e+00,  5.88343819e-01, -1.87998601e-02],
#        [-1.66263981e+00, -1.32045850e+00,  1.03107021e+00, ...,
#          5.29831617e-01,  2.56369273e-01,  7.34557526e-01]])

# %% [markdown]
# Now for classification let us make the data with quality of wine less than 7 as 0(bad) and equal to or more tha 7 as 1(good)

# %% [markdown]
# # Taking Care of class imbalace

# %%
# !pip install imblearn

# %%
from imblearn.over_sampling import SMOTE

# %%
y.value_counts()
# Out:
# 5    624
# 6    590
# 7    187
# 4     47
# 8     16
# Name: quality, dtype: int64

# %%
oversample=SMOTE()
x,y=oversample.fit_resample(x,y)

# %%
y.value_counts()
# Out:
# 7    624
# 5    624
# 8    624
# 6    624
# 4    624
# Name: quality, dtype: int64

# %% [markdown]
# # Label Binarization

# %%
y=y.apply(lambda y_value:1 if y_value>=7 else 0)
y
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 3115    1
# 3116    1
# 3117    1
# 3118    1
# 3119    1
# Name: quality, Length: 3120, dtype: int64

# %%
x
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0          7.400000          0.700000     0.000000        1.900000   0.076000
# 1          7.800000          0.880000     0.000000        2.600000   0.098000
# 2          7.800000          0.760000     0.040000        2.300000   0.092000
# 3         11.200000          0.280000     0.560000        1.900000   0.075000
# 4          7.400000          0.700000     0.000000        1.900000   0.076000
# ...             ...               ...          ...             ...        ...
# 3115       7.311986          0.368801     0.304401        1.888014   0.066079
# 3116       8.625771          0.338147     0.411473        2.066627   0.064666
# 3117       8.820550          0.477534     0.402466        2.532877   0.074027
# 3118       7.205028          0.379497     0.309749        1.994972   0.056453
# 3119      10.461061          0.425859     0.439264        2.244561   0.068881
#
# ...

# %% [markdown]
# # Creating the training and testing data sets

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier


from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=21)

# %% [markdown]
# # Machine Learning Model for classification:

# %%
#classification Model Function

def classification(model,x,y):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=21)
    
    #training the model
    model.fit(x_train,y_train)
    
    #Predicting y_test
    pred=model.predict(x_test)
    
    #accuracy score
    acc_score=(accuracy_score(y_test,pred))*100
    print('Accuracy Score: ',acc_score)
    
    #classification report
    class_report=classification_report(y_test,pred)
    print('\nClassification Report \n',class_report)
    
    #cross Validation score
    cv_score=(cross_val_score(model,x,y,cv=5).mean())*100
    print('Cross Validation Score:',cv_score)
    
     # Result of accuracy minus cv scores
    result = acc_score - cv_score
    print("\nAccuracy Score - Cross Validation Score is", result)

# %%
#linear regression model

model=LogisticRegression()
classification(model,x,y)
# Out:
# Accuracy Score:  90.38461538461539
#
# Classification Report
#                precision    recall  f1-score   support
#
#            0       0.93      0.91      0.92       391
#            1       0.86      0.89      0.87       233
#
#     accuracy                           0.90       624
#    macro avg       0.90      0.90      0.90       624
# weighted avg       0.91      0.90      0.90       624
#
# Cross Validation Score: 87.94871794871796
#
# Accuracy Score - Cross Validation Score is 2.435897435897431

# %%
#support Vector Classifer

model=SVC()
classification(model,x,y)
# Out:
# Accuracy Score:  80.92948717948718
#
# Classification Report
#                precision    recall  f1-score   support
#
#            0       0.81      0.91      0.86       391
#            1       0.81      0.64      0.72       233
#
#     accuracy                           0.81       624
#    macro avg       0.81      0.78      0.79       624
# weighted avg       0.81      0.81      0.80       624
#
# Cross Validation Score: 79.35897435897436
#
# Accuracy Score - Cross Validation Score is 1.5705128205128176

# %%
model=DecisionTreeClassifier()
classification(model,x,y)
# Out:
# Accuracy Score:  92.46794871794873
#
# Classification Report
#                precision    recall  f1-score   support
#
#            0       0.95      0.93      0.94       391
#            1       0.88      0.92      0.90       233
#
#     accuracy                           0.92       624
#    macro avg       0.92      0.92      0.92       624
# weighted avg       0.93      0.92      0.93       624
#
# Cross Validation Score: 88.9423076923077
#
# Accuracy Score - Cross Validation Score is 3.525641025641036

# %%
# Random Forest Classifier

model=RandomForestClassifier()
classification(model, x, y)
# Out:
# Accuracy Score:  95.83333333333334
#
# Classification Report
#                precision    recall  f1-score   support
#
#            0       0.98      0.95      0.97       391
#            1       0.93      0.97      0.95       233
#
#     accuracy                           0.96       624
#    macro avg       0.95      0.96      0.96       624
# weighted avg       0.96      0.96      0.96       624
#
# Cross Validation Score: 92.59615384615383
#
# Accuracy Score - Cross Validation Score is 3.2371794871795174

# %% [markdown]
# From the above machine learning models we observe that Random forest gives us the best accuracy

# %%
final_model=RandomForestClassifier()
classifer=final_model.fit(x_train,y_train)
pred=final_model.predict(x_test)
acc=(accuracy_score(y_test,pred))*100
print('Accuracy score for the Best Model is :',acc)
# Out:
# Accuracy score for the Best Model is : 95.99358974358975

# %% [markdown]
# # AUC ROC Curve

# %%
from sklearn import metrics

# %%
disp = metrics.plot_roc_curve(final_model, x_test, y_test)
disp.figure_.suptitle("ROC Curve")
plt.show()
